# %%
import pandas as pd
import datetime
from matplotlib import pyplot as plt
#pd.__version__

# %%
xlsx = pd.ExcelFile('data.xlsx')
df = pd.read_excel(xlsx, 'combined')
df = df.fillna(0)
print(df)
# Out:
#                   Date  Unplanned  Planned
# 0  2019-12-18 00:00:00      13000      0.0
# 1  2019-12-19 00:00:00      12535      0.0
# 2  2019-12-20 00:00:00      13154      0.0
# 3  2019-12-21 00:00:00      14294      0.0
# 4  2019-12-22 00:00:00      12956      0.0
# ..                 ...        ...      ...
# 75 2020-03-06 00:00:00      10728   4660.0
# 76 2020-03-07 00:00:00      11868   5430.0
# 77 2020-03-08 00:00:00      12077   4963.0
# 78 2020-03-10 17:50:00      12046   6155.0
# 79 2020-03-18 16:50:00      11041   5547.0
#
# [80 rows x 3 columns]

# %%
# %matplotlib inline
x = df.Date
y = df.Unplanned
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,y)
